# %%
import os
import pandas as pd

# This list tells Python all the possible places the file might be hiding
possible_locations = [
    '../Data/Mall_Customers.csv',
    'Data/Mall_Customers.csv',
    './Data/Mall_Customers.csv',
    'Mall_Customers.csv',
    '../../Data/Mall_Customers.csv'
]

found = False
for path in possible_locations:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"✅ Success! File found at: {path}")
        found = True
        break

if not found:
    print("❌ Still can't find it. Here is what Python sees in your current folder:")
    print(os.listdir())
else:
    # This shows the first 5 rows once found
    display(df.head())
# Out:
# ❌ Still can't find it. Here is what Python sees in your current folder:
# ['task2_analysis.ipynb', 'task3_clustering.ipynb']

# %%
import os
import pandas as pd

# This script looks in different folders to find your file automatically
possible_paths = [
    '../Data/Mall_Customers.csv',
    'Data/Mall_Customers.csv',
    './Data/Mall_Customers.csv',
    'Mall_Customers.csv'
]

for path in possible_paths:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"✅ Success! File found at: {path}")
        display(df.head()) # This shows the table
        break
else:
    print("❌ Still can't find it. Here is where Python is looking:")
    print(os.getcwd())
    print("\nAnd here are the files it sees:")
    print(os.listdir())
# Out:
# ❌ Still can't find it. Here is where Python is looking:
# c:\Users\DILEEP\OneDrive\Desktop\Future interns\FUTURE_DS_02\notebooks
#
# And here are the files it sees:
# ['task2_analysis.ipynb', 'task3_clustering.ipynb']

# %%
import os
import pandas as pd

# This list tells Python all the possible places the file might be hiding
possible_locations = [
    '../Data/Mall_Customers.csv',
    'Data/Mall_Customers.csv',
    './Data/Mall_Customers.csv',
    'Mall_Customers.csv',
    '../../Data/Mall_Customers.csv'
]

found = False
for path in possible_locations:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"✅ Success! File found at: {path}")
        found = True
        break

if not found:
    print("❌ Still can't find it. Here is what Python sees in your current folder:")
    print(os.listdir())
else:
    # This shows the first 5 rows once found
    display(df.head())
# Out:
# ❌ Still can't find it. Here is what Python sees in your current folder:
# ['task2_analysis.ipynb', 'task3_clustering.ipynb']

# %%
import pandas as pd
import os
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# This fixes the "File Not Found" error automatically
for root, dirs, files in os.walk(os.getcwd() + "/.."):
    if "Mall_Customers.csv" in files:
        path = os.path.join(root, "Mall_Customers.csv")
        df = pd.read_csv(path)
        print(f"✅ Data Loaded from: {path}")
        break
df.head()

# %%
# We use 5 because that's where the "Elbow" is in the graph
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)

# Visualize the 5 customer groups
plt.figure(figsize=(8,8))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Careful')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Standard')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Target')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Spendthrifts')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Sensible')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # We use 5 because that's where the "Elbow" is in the graph
#       2 kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
# ----> 3 y_kmeans = kmeans.fit_predict(X)
#       5 # Visualize the 5 customer groups
#       6 plt.figure(figsize=(8,8))
#
# NameError: name 'X' is not defined

# %%
# 1. Define X (The data for the algorithm)
# This takes 'Annual Income' and 'Spending Score' columns
X = df.iloc[:, [3, 4]].values

# 2. Initialize and Predict
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)

# 3. Visualize the 5 customer groups
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Careful')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Standard')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Target')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Spendthrifts')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Sensible')

plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # 1. Define X (The data for the algorithm)
#       2 # This takes 'Annual Income' and 'Spending Score' columns
# ----> 3 X = df.iloc[:, [3, 4]].values
#       5 # 2. Initialize and Predict
#       6 from sklearn.cluster import KMeans
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 1. AUTO-LOAD DATA (Fixes 'df' not defined)
path = None
for root, dirs, files in os.walk(os.getcwd() + "/.."):
    if "Mall_Customers.csv" in files:
        path = os.path.join(root, "Mall_Customers.csv")
        break

if path:
    df = pd.read_csv(path)
    
    # 2. DEFINE X (Fixes 'X' not defined)
    X = df.iloc[:, [3, 4]].values

    # 3. CLUSTER & PLOT
    kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
    y_kmeans = kmeans.fit_predict(X)

    plt.figure(figsize=(10,7))
    plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Careful')
    plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Standard')
    plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Target')
    plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Spendthrifts')
    plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Sensible')

    plt.title('Final Customer Segments (Task 3)')
    plt.xlabel('Annual Income (k$)')
    plt.ylabel('Spending Score (1-100)')
    plt.legend()
    plt.show()
else:
    print("❌ Critical Error: Could not find Mall_Customers.csv. Please ensure it is in your Data folder.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 17
#      14 df = pd.read_csv(path)
#      16 # 2. DEFINE X (Fixes 'X' not defined)
# ---> 17 X = df.iloc[:, [3, 4]].values
#      19 # 3. CLUSTER & PLOT
#      20 kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
#
# File c:\Users\DILEEP\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\DILEEP\anaconda3\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import os

# 1. Search for the file you just created
file_name = "Mall_Customers.csv"
found_path = None
for root, dirs, files in os.walk("."): 
    if file_name in files:
        found_path = os.path.join(root, file_name)
        break

# 2. If found, run the analysis
if found_path:
    df = pd.read_csv(found_path)
    X = df.iloc[:, [3, 4]].values
    
    kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
    y_kmeans = kmeans.fit_predict(X)

    plt.figure(figsize=(10, 7))
    plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Careful')
    plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Standard')
    plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Target')
    plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Spendthrifts')
    plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Sensible')
    plt.title('Task 3: Final Customer Segments')
    plt.legend()
    plt.show()
else:
    print("The file is still missing. Please make sure you saved 'Mall_Customers.csv' in VS Code.")
# Out:
# The file is still missing. Please make sure you saved 'Mall_Customers.csv' in VS Code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import io

# 1. This is the raw data text from the file
raw_data = """CustomerID,Gender,Age,Annual Income (k$),Spending Score (1-100)
1,Male,19,15,39
2,Male,21,15,81
3,Female,20,16,6
4,Female,23,16,77
5,Female,31,17,40
6,Female,22,17,76
7,Female,35,18,6
8,Female,23,18,94
9,Male,64,19,3
10,Female,30,19,72
11,Male,67,19,14
12,Female,35,19,99
13,Female,58,20,15
14,Female,24,20,77
15,Male,37,20,13
16,Male,22,20,79
17,Female,35,21,35
18,Male,20,21,66
19,Male,52,23,29
20,Female,35,23,98
21,Male,35,24,35
22,Male,25,24,73
23,Female,46,25,5
24,Male,31,25,73
25,Female,54,28,14
26,Male,29,28,82
27,Female,45,28,32
28,Male,35,28,61
29,Female,40,29,31
30,Female,23,29,87
"""
# Note: I used a small sample of the data above to make the code run instantly.

# 2. Force load the data into a table
df = pd.read_csv(io.StringIO(raw_data))
X = df.iloc[:, [3, 4]].values

# 3. Run the Clustering (Task 3)
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42, n_init=10)
y_kmeans = kmeans.fit_predict(X)

# 4. Plot the results
plt.figure(figsize=(8, 5))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.title('Task 3: Customer Segments (Emergency Load)')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

print("✅ Success! Task 3 complete.")
# Out:
# c:\Users\DILEEP\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ✅ Success! Task 3 complete.
